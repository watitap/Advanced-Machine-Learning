# %% [markdown]
# ## Assignment 10

# %%
import pandas as pd

# %%
data = pd.read_csv('annual-tree-data-file-2014-1.csv')
data
# Out:
#                                Location  \
# 0      Outside 0 (Sunny Gardens Parade)
# 1       Outside (The Burroughs Library)
# 2       Outside (The Burroughs Library)
# 3       Outside (The Burroughs Library)
# 4       Outside (The Burroughs Library)
# ...                                 ...
# 42221   Outside 37-40 (Edgeworth Close)
# 42222   Outside 37-40 (Edgeworth Close)
# 42223   Outside 37-40 (Edgeworth Close)
# 42224   Outside 25-28 (Edgeworth Close)
# 42225                               NaN
#
#                                              Ward  \
# 0      Hendon (A)                              \n
# 1      Hendon (A)                              \n
# 2      Hendon (A)                              \n
# 3      Hendon (A)                              \n
# 4      Hendon (A)                              \n
# ...                                           ...
# 42221  West Hendon (A)                         \n
# 42222  West Hendon (A)                         \n
# ...

# %%
# Slice the result for first 20 rows
print (data[0:20]['Ward'])
# Out:
# 0     Hendon (A)                              \n
# 1     Hendon (A)                              \n
# 2     Hendon (A)                              \n
# 3     Hendon (A)                              \n
# 4     Hendon (A)                              \n
# 5     Hendon (A)                              \n
# 6     Burnt Oak (A)                           \n
# 7     Burnt Oak (A)                           \n
# 8     Burnt Oak (A)                           \n
# 9     Burnt Oak (A)                           \n
# 10    Burnt Oak (A)                           \n
# 11    Burnt Oak (A)                           \n
# 12    Burnt Oak (A)                           \n
# 13    Burnt Oak (A)                           \n
# 14    Burnt Oak (A)                           \n
# 15    Burnt Oak (A)                           \n
# 16    Burnt Oak (A)                           \n
# 17    Burnt Oak (A)                           \n
# 18    Burnt Oak (A)                           \n
# ...

# %%
# Slice the result for last 20 rows
print (data[42205:42225]['Ward'])
# Out:
# 42205    West Hendon (A)                         \n
# 42206    West Hendon (A)                         \n
# 42207    West Hendon (A)                         \n
# 42208    West Hendon (A)                         \n
# 42209    West Hendon (A)                         \n
# 42210    West Hendon (A)                         \n
# 42211    West Hendon (A)                         \n
# 42212    West Hendon (A)                         \n
# 42213    West Hendon (A)                         \n
# 42214    West Hendon (A)                         \n
# 42215    West Hendon (A)                         \n
# 42216    West Hendon (A)                         \n
# 42217    West Hendon (A)                         \n
# 42218    West Hendon (A)                         \n
# 42219    West Hendon (A)                         \n
# 42220    West Hendon (A)                         \n
# 42221    West Hendon (A)                         \n
# 42222    West Hendon (A)                         \n
# ...

# %%
# Use the multi-axes indexing funtion
print (data.loc[:,['Location','Age Class']])
# Out:
#                                Location        Age Class
# 0      Outside 0 (Sunny Gardens Parade)  Mature
# 1       Outside (The Burroughs Library)
# 2       Outside (The Burroughs Library)
# 3       Outside (The Burroughs Library)  Semi-Mature
# 4       Outside (The Burroughs Library)  Early
# ...                                 ...              ...
# 42221   Outside 37-40 (Edgeworth Close)  Early Mature
# 42222   Outside 37-40 (Edgeworth Close)  Young
# 42223   Outside 37-40 (Edgeworth Close)  Early Mature
# 42224   Outside 25-28 (Edgeworth Close)  Semi-Mature
# 42225                               NaN
#
# [42226 rows x 2 columns]

# %%
# Use the multi-axes indexing funtion
print (data.loc[[1,9,21],['Location','Age Class']])
# Out:
#                            Location        Age Class
# 1   Outside (The Burroughs Library)
# 9       in park railings by plot 37  Early Mature
# 21         rear of sheds by plot 14  Early

# %%
# Use the multi-axes indexing funtion
print (data.loc[10:25,['Ward','Height']])
# Out:
#                                           Ward Height
# 10  Burnt Oak (A)                           \n   5.0m
# 11  Burnt Oak (A)                           \n   4.0m
# 12  Burnt Oak (A)                           \n   5.0m
# 13  Burnt Oak (A)                           \n   4.0m
# 14  Burnt Oak (A)                           \n   3.0m
# 15  Burnt Oak (A)                           \n   3.0m
# 16  Burnt Oak (A)                           \n   3.0m
# 17  Burnt Oak (A)                           \n   4.0m
# 18  Burnt Oak (A)                           \n   3.0m
# 19  Burnt Oak (A)                           \n   3.5m
# 20  Burnt Oak (A)                           \n  11.0m
# 21  Burnt Oak (A)                           \n   3.0m
# 22  Burnt Oak (A)                           \n   3.0m
# 23  Burnt Oak (A)                           \n   3.0m
# 24  Burnt Oak (A)                           \n   3.0m
# 25  Burnt Oak (A)                           \n   3.0m
